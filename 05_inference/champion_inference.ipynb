# %% [markdown]
# # Inference on OOT data

# %% [markdown]
# Using both the champion model, we will score the inference dataframe and save for submission

# %% [markdown]
# First let's compare the train, test and OOT performance of the XG Boost and Catboost models to determine which model we should use for inference

# %% [markdown]
# ### Import Libraries and Path

# %% [markdown]
# Libraries

# %%
import os

import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import catboost as cb

print("NumPy version:", np.__version__)
print("CatBoost version:", cb.__version__)
# Out:
# NumPy version: 1.24.4
# CatBoost version: 1.2.5

# %% [markdown]
# Data path

# %%
data_path_in  = "C:/Users/Ahmed/OneDrive/Documents/projects/procore/01_data/inbound/"
data_path_out = "C:/Users/Ahmed/OneDrive/Documents/projects/procore/01_data/outbound/"

# %%
function_path = "C:/Users/Ahmed/OneDrive/Documents/projects/procore/06_functions/"

# %% [markdown]
# ### Load Performance Data

# %%
print("\nXGBoost Performance:\n\n")

pd.read_csv(data_path_out + 'xgb/model_performance.csv')
# Out:
# XGBoost Performance:
#      Dataset        RMSE       R^2
# 0      Train  103.786528  0.446058
# 1       Test  124.024431  0.422472
# 2        OOT  201.894417  0.143924
# 3  CV (Mean)  124.310478  0.344022
# 4  CV Fold 1  113.933711  0.308497
# 5  CV Fold 2  107.061988  0.371114
# 6  CV Fold 3  116.574085  0.436248
# 7  CV Fold 4  120.438698  0.338384
# 8  CV Fold 5  163.543908  0.265867

# %%
print("\nCatboost Performance:\n\n")
pd.read_csv(data_path_out + 'catboost/model_performance.csv')
# Out:
# Catboost Performance:
#      Dataset        RMSE       R^2
# 0      Train   99.042034  0.495546
# 1       Test  116.255507  0.492559
# 2        OOT  201.895335  0.143916
# 3  CV Fold 1  111.130061  0.342111
# 4  CV Fold 2  100.622342  0.444492
# 5  CV Fold 3  106.546684  0.529062
# 6  CV Fold 4  114.533518  0.401672
# 7  CV Fold 5  160.668779  0.291452
# 8    CV Mean  118.700277  0.401758

# %% [markdown]
# ##### Though both models under perform on a OOT sample of 200 listings, the Catboost model performs better than the XG Boost model on Train, Test and CV mean RMSE and R^2. Hence it is the model we will opt for.

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv(data_path_in + 'inference.csv')

print("df shape:", df.shape)
# Out:
# df shape: (500, 82)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 82 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        500 non-null    int64
#  1   id                                500 non-null    int64
#  2   listing_url                       500 non-null    object
#  3   scrape_id                         500 non-null    float64
#  4   last_scraped                      500 non-null    object
#  5   name                              499 non-null    object
#  6   summary                           482 non-null    object
#  7   space                             353 non-null    object
#  8   description                       489 non-null    object
#  9   neighborhood_overview             315 non-null    object
#  10  notes                             249 non-null    object
#  11  transit                           313 non-null    object
#  12  access                            327 non-null    object
#  13  interaction                       305 non-null    object
#  14  house_rules                       327 non-null    object
#  15  picture_url                       500 non-null    object
#  16  host_id                           500 non-null    int64
#  17  host_url                          500 non-null    object
#  18  host_name                         500 non-null    object
#  19  host_since                        500 non-null    object
#  20  host_location                     500 non-null    object
#  21  host_about                        310 non-null    object
#  22  host_response_time                343 non-null    object
#  23  host_response_rate                343 non-null    object
#  24  host_is_superhost                 500 non-null    object
#  25  host_thumbnail_url                500 non-null    object
#  26  host_picture_url                  500 non-null    object
#  27  host_neighborhood                 310 non-null    object
#  28  host_verifications                500 non-null    object
#  29  host_has_profile_pic              500 non-null    object
#  30  host_identity_verified            500 non-null    object
#  31  street                            500 non-null    object
#  32  neighborhood                      374 non-null    object
#  33  city                              500 non-null    object
#  34  suburb                            500 non-null    object
#  35  state                             497 non-null    object
#  36  zipcode                           498 non-null    float64
#  37  smart_location                    500 non-null    object
#  38  country_code                      500 non-null    object
#  39  country                           500 non-null    object
#  40  latitude                          500 non-null    float64
#  41  longitude                         500 non-null    float64
#  42  is_location_exact                 500 non-null    object
#  43  property_type                     500 non-null    object
#  44  room_type                         500 non-null    object
#  45  accommodates                      500 non-null    int64
#  46  bathrooms                         215 non-null    float64
#  47  bedrooms                          216 non-null    float64
#  48  beds                              499 non-null    float64
#  49  bed_type                          500 non-null    object
#  50  amenities                         500 non-null    object
#  51  security_deposit                  353 non-null    float64
#  52  cleaning_fee                      384 non-null    float64
#  53  guests_included                   500 non-null    int64
#  54  extra_people                      500 non-null    int64
#  55  minimum_nights                    500 non-null    int64
#  56  maximum_nights                    500 non-null    int64
#  57  calendar_updated                  500 non-null    object
#  58  has_availability                  500 non-null    object
#  59  availability_30                   500 non-null    int64
#  60  availability_60                   500 non-null    int64
#  61  availability_90                   500 non-null    int64
#  62  availability_365                  500 non-null    int64
#  63  calendar_last_scraped             500 non-null    object
#  64  number_of_reviews                 500 non-null    int64
#  65  first_review                      385 non-null    object
#  66  last_review                       385 non-null    object
#  67  review_scores_rating              376 non-null    float64
#  68  review_scores_accuracy            376 non-null    float64
#  69  review_scores_cleanliness         376 non-null    float64
#  70  review_scores_checkin             376 non-null    float64
#  71  review_scores_communication       376 non-null    float64
#  72  review_scores_location            376 non-null    float64
#  73  review_scores_value               376 non-null    float64
#  74  requires_license                  500 non-null    object
#  75  license                           0 non-null      float64
#  76  instant_bookable                  500 non-null    object
#  77  cancellation_policy               500 non-null    object
#  78  require_guest_profile_picture     500 non-null    object
#  79  require_guest_phone_verification  500 non-null    object
#  80  calculated_host_listings_count    500 non-null    int64
#  81  reviews_per_month                 385 non-null    float64
# dtypes: float64(18), int64(14), object(50)
# memory usage: 320.4+ KB

# %%
df.sample(3)
# Out:
#      Unnamed: 0        id                            listing_url  \
# 72        10345  18884447  https://www.airbnb.com/rooms/18884447
# 325        4909  11258658  https://www.airbnb.com/rooms/11258658
# 399        3627   9139846   https://www.airbnb.com/rooms/9139846
#
#         scrape_id last_scraped  \
# 72   2.018120e+13    12/7/2018
# 325  2.018120e+13    12/7/2018
# 399  2.018120e+13    12/7/2018
#
#                                                   name  \
# 72   Large Bright Room With En Suite in Sunny Port ...
# 325  Top reviews next to public transport 15mins to...
# 399                     Studio/unit, beautiful gardens
#
#                                                summary  \
# 72   A bright spacious apartment, beach at the end ...
# 325  Metres from the Gardiner train station and tra...
# 399  A beautiful slice of heaven.  Charming locatio...
#
#                                                  space  \
# 72                                                 NaN
# 325  There are two bedrooms in our apartment both b...
# 399  Lovely established garden setting where you ca...
#
#                                            description  \
# 72   A bright spacious apartment, beach at the end ...
# 325  Metres from the Gardiner train station and tra...
# 399  A beautiful slice of heaven.  Charming locatio...
#
#                                  neighborhood_overview  \
# 72   A beautiful, quiet neighbourhood with the beac...
# 325  Glen Iris, south-east of the city, is leafy, w...
# 399  Close to the beach and the gateway to the Morn...
#
#                                                  notes  \
# 72                                                 NaN
# 325  We have a little dog, Ron. He is a very friend...
# 399  I have a dog, so please ask if you would like ...
#
#                                                transit  \
# 72   Street parking is available  and the 109 tram ...
# 325  The apartment is just metres to the new Gardin...
# 399  The train station is only 10 minutes away by c...
#
#                                                 access  \
# 72   You'll have access to the living room, kitchen...
# 325  Guests will have access to most parts of the a...
# 399  You have access to the garden and the Al-fresc...
#
#                                            interaction  \
# 72   I will be contactable via phone, text or email...
# 325  Ruby and Jesse are both a 9 to 5 working profe...
# 399      I would be happy to help though out your stay
#
#                                            house_rules  \
# 72                                              #NAME?
# 325  The most important thing for us would be mindf...
# 399  I live in a quiet area and am always considera...
#
#                                            picture_url   host_id  \
# 72   https://a0.muscache.com/im/pictures/1ea6eceb-3...  16510225
# 325  https://a0.muscache.com/im/pictures/a6d69f9a-1...    957970
# 399  https://a0.muscache.com/im/pictures/1a7d80f8-b...  47600522
#
#                                        host_url host_name  host_since  \
# 72   https://www.airbnb.com/users/show/16510225     Gemma    6/7/2014
# 325    https://www.airbnb.com/users/show/957970      Ruby   8/11/2011
# 399  https://www.airbnb.com/users/show/47600522    Carole  10/28/2015
#
#                       host_location  \
# 72              Victoria, Australia
# 325  Melbourne, Victoria, Australia
# 399             Victoria, Australia
#
#                                             host_about  host_response_time  \
# 72   I am a twin born in NZ and raised in Ireland n...                 NaN
# 325  I have been lived in Melbourne for 17 years. I...  within a few hours
# 399                                                NaN      within an hour
#
#     host_response_rate host_is_superhost  \
# 72                 NaN                 f
# 325               100%                 t
# 399               100%                 t
#
#                                     host_thumbnail_url  \
# 72   https://a0.muscache.com/im/pictures/47f5c9ec-e...
# 325  https://a0.muscache.com/im/pictures/3b4acd3d-7...
# 399  https://a0.muscache.com/im/pictures/886604b4-8...
#
#                                       host_picture_url host_neighborhood  \
# 72   https://a0.muscache.com/im/pictures/47f5c9ec-e...    Port Melbourne
# 325  https://a0.muscache.com/im/pictures/3b4acd3d-7...         Glen Iris
# 399  https://a0.muscache.com/im/pictures/886604b4-8...               NaN
#
#                                     host_verifications host_has_profile_pic  \
# 72   ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 325  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 399                      ['email', 'phone', 'reviews']                    t
#
#     host_identity_verified                           street    neighborhood  \
# 72                       f   Port Melbourne, VIC, Australia  Port Melbourne
# 325                      t        Glen Iris, VIC, Australia       Glen Iris
# 399                      f  Frankston South, VIC, Australia             NaN
#
#              city           suburb state  zipcode              smart_location  \
# 72   Port Phillip   Port Melbourne   VIC   3207.0   Port Melbourne, Australia
# 325   Stonnington        Glen Iris   VIC   3146.0        Glen Iris, Australia
# 399     Frankston  Frankston South   VIC   3199.0  Frankston South, Australia
#
#     country_code    country   latitude   longitude is_location_exact  \
# 72            AU  Australia -37.838501  144.936597                 t
# 325           AU  Australia -37.856580  145.051901                 t
# 399           AU  Australia -38.164599  145.133769                 t
#
#     property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 72      Apartment     Private room             1        2.0       1.0   1.0
# 325     Apartment     Private room             2        1.0       1.0   1.0
# 399      Bungalow  Entire home/apt             2        NaN       NaN   1.0
#
#      bed_type                                          amenities  \
# 72   Real Bed  {Wifi,Kitchen,Heating,Washer,Dryer,"Smoke dete...
# 325  Real Bed  {TV,Internet,Wifi,Kitchen,Gym,Breakfast,"Pets ...
# 399  Real Bed  {TV,Wifi,Kitchen,"Free parking on premises","S...
#
#      security_deposit  cleaning_fee  guests_included  extra_people  \
# 72              200.0           0.0                1             0
# 325               0.0          16.0                1            22
# 399               NaN           NaN                2            15
#
#      minimum_nights  maximum_nights calendar_updated has_availability  \
# 72                5            1125    12 months ago                t
# 325               2            1125     2 months ago                t
# 399               1              31      5 weeks ago                t
#
#      availability_30  availability_60  availability_90  availability_365  \
# 72                 0                0                0                 0
# 325               22               22               45               320
# 399                5               29               54               329
#
#     calendar_last_scraped  number_of_reviews first_review last_review  \
# 72              12/7/2018                  1    6/24/2017   6/24/2017
# 325             12/7/2018                 32    2/23/2016  11/26/2018
# 399             12/7/2018                195   11/23/2015  11/22/2018
#
#      review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 72                  100.0                    10.0                       10.0
# 325                  96.0                    10.0                       10.0
# 399                  93.0                    10.0                        9.0
#
#      review_scores_checkin  review_scores_communication  \
# 72                    10.0                         10.0
# 325                   10.0                         10.0
# 399                   10.0                         10.0
#
#      review_scores_location  review_scores_value requires_license  license  \
# 72                     10.0                 10.0                f      NaN
# 325                    10.0                 10.0                f      NaN
# 399                     9.0                 10.0                f      NaN
#
#     instant_bookable          cancellation_policy  \
# 72                 f                     flexible
# 325                f  strict_14_with_grace_period
# 399                f  strict_14_with_grace_period
#
#     require_guest_profile_picture require_guest_phone_verification  \
# 72                              f                                f
# 325                             f                                f
# 399                             f                                f
#
#      calculated_host_listings_count  reviews_per_month
# 72                                1               0.06
# 325                               1               0.94
# 399                               1               5.27

# %% [markdown]
# ### Preprocess data

# %%
import sys
sys.path.append(function_path)

import preprocessor_inference
from preprocessor_inference import *

df_cleaned = preprocess_data(df)

print("df shape:", df.shape)
print("df_cleaned: ", df_cleaned.shape)
# Out:
# df shape: (500, 82)
# df_cleaned:  (500, 75)

# %% [markdown]
# ### Organize features

# %% [markdown]
# Organize features to numerical, categorical, target, drop features

# %%
drop_features = ['zipcode', 'price']  

numerical_features = df_cleaned.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_features = [feature for feature in numerical_features if feature not in drop_features]

categorical_features = df_cleaned.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_features = [feature for feature in categorical_features if feature not in drop_features]

target = ['price']

print("drop_features:\t\t", len(drop_features))
print("numerical_features:\t", len(numerical_features))
print("categorical_features:\t", len(categorical_features))
print("target:\t\t\t", len(target))
# Out:
# drop_features:		 2
# numerical_features:	 31
# categorical_features:	 43
# target:			 1

# %% [markdown]
# ### Inference

# %% [markdown]
# Load model

# %%
from catboost import CatBoostRegressor

# Load the saved CatBoost model
catboost_model = CatBoostRegressor()

model_folder = "C:/Users/Ahmed/OneDrive/Documents/projects/procore/07_artifacts/"
model_filename = "catboost_model.cbm"
model_path = os.path.join(model_folder, model_filename)

catboost_model.load_model(model_path)

# %%
subset_columns = ['id'] + catboost_model.feature_names_
df_final = df_cleaned[subset_columns]

drop_features = ['zipcode', 'price']  

numerical_features = df_final.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_features = [feature for feature in numerical_features if feature not in drop_features]

categorical_features = df_final.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_features = [feature for feature in categorical_features if feature not in drop_features]

print("numerical_features:\t", len(numerical_features))
print("categorical_features:\t", len(categorical_features))
print("df_final shape:\t\t", df_final.shape)
# Out:
# numerical_features:	 29
# categorical_features:	 30
# df_final shape:		 (500, 60)

# %%
from catboost import Pool

# Create a Pool object for the prediction data, specifying the categorical features
df_pool = Pool(df_final, cat_features=categorical_features)

# Perform predictions
predictions = catboost_model.predict(df_pool)

# Add the predictions to your DataFrame
df_final['predicted_price'] = predictions
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_57596\745663639.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['predicted_price'] = predictions

# %% [markdown]
# ### Save prediction file for sumbission

# %%
df_final.head()
# Out:
#          id                     host_location host_response_time  \
# 0  28964846    Brunswick, Victoria, Australia       within a day
# 1  19648696     Werribee, Victoria, Australia     within an hour
# 2  11346949    Melbourne, Victoria, Australia            Unknown
# 3  29476373  Ferny Creek, Victoria, Australia     within an hour
# 4  21627660                             China     within an hour
#
#   host_response_rate host_is_superhost  \
# 0                81%                 f
# 1               100%                 f
# 2            Unknown                 f
# 3               100%                 f
# 4               100%                 f
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'facebook', 'jumio', 'offli...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 2  ['email', 'phone', 'facebook', 'jumio', 'gover...                    t
# 3                                          ['phone']                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                           street  \
# 0                      t        Brunswick, VIC, Australia
# 1                      f        Maidstone, VIC, Australia
# 2                      t  Caulfield North, VIC, Australia
# 3                      f        Melbourne, VIC, Australia
# 4                      f        Melbourne, VIC, Australia
#
#                 neighborhood          city           suburb state  zipcode  \
# 0                  Brunswick      Moreland        Brunswick   VIC   3056.0
# 1                  Footscray   Maribyrnong        Maidstone   VIC   3012.0
# 2                  Caulfield     Glen Eira  Caulfield North   VIC   3161.0
# 3  Central Business District     Melbourne        Melbourne   VIC   3000.0
# 4            Prahran/Windsor  Port Phillip        Melbourne   VIC   3004.0
#
#                smart_location country_code    country   latitude   longitude  \
# 0        Brunswick, Australia           AU  Australia -37.758036  144.971277
# 1        Maidstone, Australia           AU  Australia -37.782292  144.881223
# 2  Caulfield North, Australia           AU  Australia -37.872654  145.022953
# 3        Melbourne, Australia           AU  Australia -37.821687  144.955512
# 4        Melbourne, Australia           AU  Australia -37.851703  144.978613
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 f         House  Entire home/apt             4        1.0
# 1                 t         House  Entire home/apt            10        1.0
# 2                 f         House  Entire home/apt             5        1.0
# 3                 f     Apartment  Entire home/apt             2        1.0
# 4                 f     Apartment     Private room             2        1.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   2.0  Real Bed
# 1       1.0   8.0  Real Bed
# 2       1.0   4.0  Real Bed
# 3       1.0   1.0  Real Bed
# 4       1.0   1.0  Real Bed
#
#                                            amenities  security_deposit  \
# 0  {TV,Kitchen,"Free parking on premises","Smokin...             250.0
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...             600.0
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...             250.0
# 3  {TV,"Air conditioning","Paid parking off premi...             250.0
# 4  {Wifi,Pool,Kitchen,Gym,Elevator,Heating,Washer...               0.0
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0          60.0                1             0               3
# 1         140.0                6            15               3
# 2          59.0                1             0               1
# 3          59.0                1            10               1
# 4          10.0                1             0               1
#
#    maximum_nights calendar_updated has_availability  availability_30  \
# 0            1125        yesterday                t               20
# 1              90            today                t               12
# 2            1125    31 months ago                t                0
# 3               3       2 days ago                t                9
# 4              30      6 weeks ago                t               14
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               35               35               269             12/7/2018
# 1               36               64               154             12/7/2018
# 2                0                0                 0             12/7/2018
# 3               13               31                31             12/7/2018
# 4               37               37                37             12/7/2018
#
#    number_of_reviews first_review last_review  review_scores_rating  \
# 0                  0      Unknown     Unknown                  97.0
# 1                 50    7/10/2017   12/3/2018                  90.0
# 2                  0      Unknown     Unknown                  97.0
# 3                 11   10/28/2018   12/2/2018                  91.0
# 4                 16   12/24/2017  11/10/2018                  85.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                        9.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                     9.0                        9.0                    9.0
# 4                     9.0                        9.0                    9.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                     9.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                          9.0                    10.0                  9.0
# 4                          9.0                    10.0                  9.0
#
#   requires_license instant_bookable          cancellation_policy  \
# 0                f                f                     flexible
# 1                f                t                     moderate
# 2                f                f                     flexible
# 3                f                f                     moderate
# 4                f                t  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month  last_scraped_delta  \
# 0                               2               1.02                2084
# 1                               1               2.91                2084
# 2                               1               1.02                2084
# 3                               1               8.05                2084
# 4                               3               1.38                2084
#
#    host_since_delta  predicted_price
# 0              3499       146.336564
# 1              3360       194.772625
# 2              3106       155.766262
# 3              2989       128.605501
# 4              2881        79.885652

# %%
df_final.to_csv(data_path_out + 'catboost/inference_outbound.csv', index=False)
